# %%
import json
import numpy as np
import pandas as pd
import dask
import matplotlib.pyplot as plt
import dask.dataframe as dd
import dask.bag as db
from dask.distributed import Client
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
client = Client()
display(client)
# Out:
# DEBUG:asyncio:Using selector: SelectSelector
# <Client: 'tcp://127.0.0.1:54906' processes=4 threads=16, memory=31.93 GiB>

# %%
client.get_versions(check=True)
# Out:
# {'scheduler': {'host': {'python': '3.11.5.final.0',
#    'python-bits': 64,
#    'OS': 'Windows',
#    'OS-release': '10',
#    'machine': 'AMD64',
#    'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#    'byteorder': 'little',
#    'LC_ALL': 'None',
#    'LANG': 'None'},
#   'packages': {'python': '3.11.5.final.0',
#    'dask': '2024.4.1',
#    'distributed': '2024.4.1',
#    'msgpack': '1.0.3',
#    'cloudpickle': '2.2.1',
#    'tornado': '6.3.3',
#    'toolz': '0.12.0',
#    'numpy': '1.26.4',
#    'pandas': '2.1.4',
#    'lz4': '4.3.2'}},
#  'workers': {'tcp://127.0.0.1:54925': {'host': {'python': '3.11.5.final.0',
#     'python-bits': 64,
#     'OS': 'Windows',
#     'OS-release': '10',
#     'machine': 'AMD64',
#     'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'None'},
#    'packages': {'python': '3.11.5.final.0',
#     'dask': '2024.4.1',
#     'distributed': '2024.4.1',
#     'msgpack': '1.0.3',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.3',
#     'toolz': '0.12.0',
#     'numpy': '1.26.4',
#     'pandas': '2.1.4',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:54928': {'host': {'python': '3.11.5.final.0',
#     'python-bits': 64,
#     'OS': 'Windows',
#     'OS-release': '10',
#     'machine': 'AMD64',
#     'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'None'},
#    'packages': {'python': '3.11.5.final.0',
#     'dask': '2024.4.1',
#     'distributed': '2024.4.1',
#     'msgpack': '1.0.3',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.3',
#     'toolz': '0.12.0',
#     'numpy': '1.26.4',
#     'pandas': '2.1.4',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:54929': {'host': {'python': '3.11.5.final.0',
#     'python-bits': 64,
#     'OS': 'Windows',
#     'OS-release': '10',
#     'machine': 'AMD64',
#     'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'None'},
#    'packages': {'python': '3.11.5.final.0',
#     'dask': '2024.4.1',
#     'distributed': '2024.4.1',
#     'msgpack': '1.0.3',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.3',
#     'toolz': '0.12.0',
#     'numpy': '1.26.4',
#     'pandas': '2.1.4',
#     'lz4': '4.3.2'}},
#   'tcp://127.0.0.1:54934': {'host': {'python': '3.11.5.final.0',
#     'python-bits': 64,
#     'OS': 'Windows',
#     'OS-release': '10',
#     'machine': 'AMD64',
#     'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#     'byteorder': 'little',
#     'LC_ALL': 'None',
#     'LANG': 'None'},
#    'packages': {'python': '3.11.5.final.0',
#     'dask': '2024.4.1',
#     'distributed': '2024.4.1',
#     'msgpack': '1.0.3',
#     'cloudpickle': '2.2.1',
#     'tornado': '6.3.3',
#     'toolz': '0.12.0',
#     'numpy': '1.26.4',
#     'pandas': '2.1.4',
#     'lz4': '4.3.2'}}},
#  'client': {'host': {'python': '3.11.5.final.0',
#    'python-bits': 64,
#    'OS': 'Windows',
#    'OS-release': '10',
#    'machine': 'AMD64',
#    'processor': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD',
#    'byteorder': 'little',
#    'LC_ALL': 'None',
#    'LANG': 'None'},
#   'packages': {'python': '3.11.5.final.0',
#    'dask': '2024.4.1',
#    'distributed': '2024.4.1',
#    'msgpack': '1.0.3',
#    'cloudpickle': '2.2.1',
#    'tornado': '6.3.3',
#    'toolz': '0.12.0',
#    'numpy': '1.26.4',
#    'pandas': '2.1.4',
#    'lz4': '4.3.2'}}}

# %% [markdown]
# ## Does not work due to problematic data in the Json file

# %%
df = dd.read_json('All_Beauty_filtered.jsonl', lines=True)
df.head()
# Out:
# 2024-04-16 21:09:31,273 - distributed.scheduler - ERROR - Error during deserialization of the task graph. This frequently
# occurs if the Scheduler and Client have different environments.
# For more information, see
# https://docs.dask.org/en/stable/deployment-considerations.html#consistent-software-environments
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\scheduler.py:4685, in update_graph()
#    4684 try:
# -> 4685     graph = deserialize(graph_header, graph_frames).data
#    4686     del graph_header, graph_frames
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\protocol\serialize.py:448, in deserialize()
#     447 dumps, loads, wants_context = families[name]
# --> 448 return loads(header, frames)
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\protocol\serialize.py:105, in pickle_loads()
#     103         return mv
# --> 105 buffers = [
#     106     ensure_writeable_flag(ensure_memoryview(mv), w)
#     107     for mv, w in zip(buffers, header["writeable"])
#     108 ]
#     110 return pickle.loads(pik, buffers=buffers)
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\protocol\serialize.py:106, in <listcomp>()
#     103         return mv
#     105 buffers = [
# --> 106     ensure_writeable_flag(ensure_memoryview(mv), w)
#     107     for mv, w in zip(buffers, header["writeable"])
#     108 ]
#     110 return pickle.loads(pik, buffers=buffers)
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\utils.py:1107, in ensure_memoryview()
#    1106 if not isinstance(obj, memoryview):
# -> 1107     obj = memoryview(obj)
#    1109 if not obj.nbytes:
#    1110     # Drop `obj` reference to permit freeing underlying data
#
# TypeError: memoryview: a bytes-like object is required, not 'int'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 df = dd.read_json('All_Beauty_filtered.jsonl', lines=True)
# ----> 2 df.head()
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\dask_expr\_collection.py:600, in FrameBase.head(self, n, npartitions, compute)
#     598 out = new_collection(expr.Head(self, n=n, npartitions=npartitions))
#     599 if compute:
# --> 600     out = out.compute()
#     601 return out
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\dask_expr\_collection.py:453, in FrameBase.compute(self, fuse, **kwargs)
#     451     out = out.repartition(npartitions=1)
#     452 out = out.optimize(fuse=fuse)
# --> 453 return DaskMethodsMixin.compute(out, **kwargs)
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\dask\base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
#     354     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     373     dask.compute
#     374     """
# --> 375     (result,) = compute(self, traverse=False, **kwargs)
#     376     return result
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\dask\base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\Andrew Deur\anaconda3\Lib\site-packages\distributed\client.py:2232, in Client._gather(self, futures, errors, direct, local_worker)
#    2230         exc = CancelledError(key)
#    2231     else:
# -> 2232         raise exception.with_traceback(traceback)
#    2233     raise exc
#    2234 if errors == "skip":
#
# RuntimeError: Error during deserialization of the task graph. This frequently
# occurs if the Scheduler and Client have different environments.
# For more information, see
# https://docs.dask.org/en/stable/deployment-considerations.html#consistent-software-environments

# %% [markdown]
# ## Load into a Dask Bag first, then convert to a Df

# %%
json_bag = db.read_text('All_Beauty.jsonl').map(json.loads)
df = json_bag.to_dataframe()
# %time df.head()
# Out:
# c:\Users\Andrew Deur\anaconda3\Lib\site-packages\dask_expr\_collection.py:4756: FutureWarning: `from_dask_dataframe` is deprecated, please use `from_legacy_dataframe`.
#   warnings.warn(
# CPU times: total: 78.1 ms
# Wall time: 9.33 s
#    rating                                      title  \
# 0     5.0  Such a lovely scent but not overpowering.
# 1     4.0     Works great but smells a little weird.
# 2     5.0                                       Yes!
# 3     1.0                          Synthetic feeling
# 4     5.0                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1588687728923             0
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1588615855070             1
# 2  B097R46CSY  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ  1589665266052             2
# 3  B09JS339BZ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1643393630220             0
# 4  B08BZ63GMJ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1609322563534             0
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %%
print(f"Total No. Reviews: {len(df):,}")
# %time df = df[df['helpful_vote'] > 0] # Filter out reviews with no helpful votes
print(f"Total No. Reviews after Filtering: {len(df):,}")
# Out:
# Total No. Reviews: 701,528
# CPU times: total: 0 ns
# Wall time: 2 ms
# Total No. Reviews after Filtering: 187,439

# %% [markdown]
# ## 701,528 --> 187,439 Records. Most of our partitions will be empty. Let's repartition by the value we will be grouping by in our next calculation. (Should we be worried about key skew?)

# %%
df.set_index("user_id")
# Out:
# Dask DataFrame Structure:
#                 rating   title    text  images    asin parent_asin timestamp helpful_vote verified_purchase
# npartitions=1
#                float64  string  string  string  string      string     int64        int64              bool
#                    ...     ...     ...     ...     ...         ...       ...          ...               ...
# Dask Name: setindex, 5 expressions
# Expr=SetIndex(frame=Filter(frame=FromGraph(0ce749f), predicate=FromGraph(0ce749f)['helpful_vote'] > 0), _other='user_id', options={})

# %% [markdown]
# ## Are average user ratings distributed differently between verified and unverified reviews?

# %%
verified_reviews = df[df["verified_purchase"] == True].groupby("user_id")["rating"].mean()
unverified_reviews = df[df["verified_purchase"] == False].groupby("user_id")["rating"].mean()

# %%
from matplotlib.ticker import FuncFormatter

def comma_formatter(x, pos):
    return f'{int(x):,}'

# %%
formatter = FuncFormatter(comma_formatter)

hist, edges = np.histogram(verified_reviews)
plt.hist(edges[:-1], edges, weights=hist)
plt.title("Distribution of Verified Purchase Ratings")
plt.xlabel("Stars")
plt.ylabel("Count")
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()

# %%
hist, edges = np.histogram(unverified_reviews)
plt.hist(edges[:-1], edges, weights=hist)
plt.title("Distribution of Unverified Purchase Ratings")
plt.xlabel("Stars")
plt.ylabel("Count")
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()
